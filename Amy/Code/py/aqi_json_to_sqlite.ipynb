# %%
import os
import sys
import json
import pandas as pd
from datetime import datetime
from os.path import expanduser
import urllib3
from config import API_KEY
# create crosswalk for zip code / county to aqi station
# load in sqllite
# link zip code

# %%
def main():

    # API parameters
    options = {}
    options["url"] = "https://airnowapi.org/aq/data/"
    options["start_date"] = "2019-06-17"
    options["start_hour_utc"] = "15"
    options["end_date"] = "2019-06-17"
    options["end_hour_utc"] = "23"
    options["parameters"] = "o3,pm25"
    options["bbox"] = "-107.027060,25.632792,-93.228232,36.731120"
    options["data_type"] = "a"
    options["format"] = "application/json"
    options["verbose"] = "1"
    options["ext"] = "kml"
    options["api_key"] = API_KEY

    # API request URL
    REQUEST_URL = options["url"] \
                  + "?startdate=" + options["start_date"] \
                  + "t" + options["start_hour_utc"] \
                  + "&enddate=" + options["end_date"] \
                  + "t" + options["end_hour_utc"] \
                  + "&parameters=" + options["parameters"] \
                  + "&bbox=" + options["bbox"] \
                  + "&datatype=" + options["data_type"] \
                  + "&format=" + options["format"] \
                  + "&verbose=" + options["verbose"] \
                  + "&api_key=" + options["api_key"]

    try:
        # Request AirNowAPI data
        print ("Requesting AirNowAPI data...")

        # User's home directory.
        home_dir = expanduser("~")
        download_file_name = "AirNowAPI" + datetime.now().strftime("_%Y%M%d%H%M%S." + options["ext"])
        download_file = os.path.join(home_dir, download_file_name)

        # Perform the AirNow API data request
        api_data = urllib3.PoolManager()
        resp = api_data.request('GET',REQUEST_URL)

        # Download complete
        print ("Download URL: %s" % REQUEST_URL)
        print ("Download File: %s" % resp.data)
        return resp.data

    except Exception as e:
        print ("Unable perform AirNowAPI request. %s" % e)
        sys.exit(1)

# %%
if __name__ == "__main__":
    main()
# Out:
# Requesting AirNowAPI data...
# C:\Users\amy_r\Anaconda3\lib\site-packages\urllib3\connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Download URL: https://airnowapi.org/aq/data/?startdate=2019-06-16t15&enddate=2019-06-16t23&parameters=o3,pm25&bbox=-107.027060,25.632792,-93.228232,36.731120&datatype=a&format=application/json&verbose=1&api_key=9EFBDC3F-9727-474B-8AC4-B950F718C9C7
# Download File: b'[{"Latitude":32.3169,"Longitude":-106.7669,"UTC":"2019-06-16T15:00","Parameter":"OZONE","Unit":"PPB","AQI":29,"Category":1,"SiteName":"Solano Drive","AgencyName":"New Mexico Air Quality Bureau","FullAQSCode":"350130023","IntlAQSCode":"840350130023"},{"Latitude":32.310332,"Longitude":-106.751211,"UTC":"2019-06-16T15:00","Parameter":"PM2.5","Unit":"UG/M3","AQI":15,"Category":1,"SiteName":"Las Cruces ED","AgencyName":"New Mexico Air Quality Bureau","FullAQSCode":"350130025","IntlAQSCode":"840350130025"},{"Latitude":34.8147,"Longitude":-106.7397,"UTC":"2019-06-16T15:00","Parameter":"OZONE","Unit":"PPB","AQI":40,"Category":1,"SiteName":"2LL Los Lunas","AgencyName":"New Mexico Air Quality Bureau","FullAQSCode":"350610008","IntlAQSCode":"840350610008"},{"Latitude":36.187733,"Longitude":-106.698378,"UTC":"2019-06-16T15:00","Parameter":"OZONE","Unit":"PPB","AQI":36,"Category":1,"SiteName":"Coyote Ranger District","AgencyName":"New Mexico Air Quality Bureau","FullAQSCode":"350390026","IntlAQSCode":"840350390026"},{"Latitude":31.7878,"Longitude":-106.6828,"UTC":"2019-06-16T15:00","Parameter":"OZONE","Unit":"PPB","AQI":32,"Category":1,"SiteName":"Santa Teresa","AgencyName":"New Mexico Air Quality Bureau","FullAQSCode":"
# 1579   29  Louisiana Department of Environmental Quality         1
# 1580   28  Louisiana Department of Environmental Quality         1
#
#        FullAQSCode      IntlAQSCode   Latitude   Longitude Parameter  \
# 0        350130023     840350130023  32.316900 -106.766900     OZONE
# 1        350130025     840350130025  32.310332 -106.751211     PM2.5
# 2        350610008     840350610008  34.814700 -106.739700     OZONE
# 3        350390026     840350390026  36.187733 -106.698378     OZONE
# 4        350130022     840350130022  31.787800 -106.682800     OZONE
# 5        350130022     840350130022  31.787800 -106.682800     PM2.5
# 6        350010029     840350010029  35.018600 -106.651901     OZONE
# 7        350010029     840350010029  35.018600 -106.651901     PM2.5
# 8        350130008     840350130008  31.930600 -106.630600     OZONE
# 9        350010026     840350010026  35.144100 -106.604400     PM2.5
# 10       350130016     840350130016  32.003600 -106.599200     PM2.5
# 11       350010023     840350010023  35.135300 -106.584702     OZONE
# 12       350010023     840350010023  35.135300 -106.584702     PM2.5
# 13       350130021     840350130021  31.796100 -106.583900     OZONE
# 14       350431001     840350431001  35.299400 -106.548300     OZONE
# 15    840350439028  840840350439028  35.338407 -106.524292     OZONE
# 16    840350439028  840840350439028  35.338407 -106.524292     PM2.5
# 17       350011012     840350011012  35.185000 -106.507700     OZONE
# 18       481410037     840481410037  31.768056 -106.501111     OZONE
# 19       481410037     840481410037  31.768056 -106.501111     PM2.5
# 20       481410044     840481410044  31.765600 -106.455000     OZONE
# 21       481410044     840481410044  31.765600 -106.455000     PM2.5
# 22       481410058     840481410058  31.893889 -106.425556     OZONE
# 23       350130020     840350130020  32.041100 -106.409200     OZONE
# 24       481410055     840481410055  31.746700 -106.402802     PM2.5
# 25       481410029     840481410029  31.786400 -106.324200     OZONE
# 26       481410057     840481410057  31.667520 -106.287740     PM2.5
# 27       481410057     840481410057  31.667520 -106.287740     OZONE
# 28       350490021     840350490021  35.619800 -106.079700     OZONE
# 29       350490021     840350490021  35.619800 -106.079700     PM2.5
# ...            ...              ...        ...         ...       ...
# 1551     481830001     840481830001  32.378682  -94.711811     OZONE
# 1552     483739991     840483739991  30.668100  -94.673900     OZONE
# 1553     400019009     840400019009  35.750599  -94.669701     OZONE
# 1554     400019009     840400019009  35.750599  -94.669701     PM2.5
# 1555     401359021     840401359021  35.408138  -94.524414     OZONE
# 1556     401359021     840401359021  35.408138  -94.524414     PM2.5
# 1557     482450022     840482450022  29.863952  -94.317800     PM2.5
# 1558     482450022     840482450022  29.863952  -94.317800     OZONE
# 1559     482030002     840482030002  32.670600  -94.168100     OZONE
# 1560     482030002     840482030002  32.670600  -94.168100     PM2.5
# 1561      51430006     840051430006  36.011703  -94.167436     OZONE
# 1562      51130003     840051130003  34.454400  -94.143300     OZONE
# 1563      51430005     840051430005  36.179700  -94.116700     OZONE
# 1564      51430005     840051430005  36.179700  -94.116700     PM2.5
# 1553             STILWELL CASTNET & NCORE  2019-06-16T23:00    PPB
# 1554             STILWELL CASTNET & NCORE  2019-06-16T23:00  UG/M3
# 1555                               ROLAND  2019-06-16T23:00    PPB
# 1556                               ROLAND  2019-06-16T23:00  UG/M3
# 1557                         Hamshire C64  2019-06-16T23:00  UG/M3
# 1558                         Hamshire C64  2019-06-16T23:00    PPB
# 1559                          Karnack C85  2019-06-16T23:00    PPB
# 1560                          Karnack C85  2019-06-16T23:00  UG/M3
# 1561                         Fayetteville  2019-06-16T23:00    PPB
# 1562                              EAGLEMT  2019-06-16T23:00    PPB
# 1563                             SPRNGDLE  2019-06-16T23:00    PPB
# 1564                             SPRNGDLE  2019-06-16T23:00  UG/M3
# 1565                 Texarkana New Boston  2019-06-16T23:00  UG/M3
# 1566                     Beaumont C2/C112  2019-06-16T23:00    PPB
# 1567                      Nederland C1035  2019-06-16T23:00    PPB
# 1568  SETRPC 43 Jefferson Co Airport C643  2019-06-16T23:00    PPB
# 1569       Port Arthur West C28/C128/C228  2019-06-16T23:00    PPB
# 1570              SETRPC Port Arthur C628  2019-06-16T23:00    PPB
# 1571         Thomas Jefferson School C303  2019-06-16T23:00  UG/M3
# 1572           SETRPC 40 Sabine Pass C640  2019-06-16T23:00    PPB
# 1573          SETRPC Mauriceville 42 C642  2019-06-16T23:00  UG/M3
# 1574          SETRPC Mauriceville 42 C642  2019-06-16T23:00    PPB
# 1575                                Dixie  2019-06-16T23:00    PPB
# 1576                  West Orange C9/C141  2019-06-16T23:00    PPB
# 1577                   Shreveport Airport  2019-06-16T23:00    PPB
# 1578                   Shreveport Airport  2019-06-16T23:00  UG/M3
# 1579                               Vinton  2019-06-16T23:00    PPB
# 1580                              Carlyss  2019-06-16T23:00    PPB
#
# [1581 rows x 11 columns]

# %%
# CREATE TABLE "output" (
# 	"site_autoid"	INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
# 	"Longitude"	NUMERIC,
# 	"Latitude"	NUMERIC,
# 	"UTC"	TEXT,
# 	"Parameter"	TEXT,
# 	"Unit"	TEXT,
# 	"Value"	NUMERIC,
# 	"AQI"	NUMERIC,
# 	"Category"	NUMERIC,
# 	"SiteName"	TEXT,
# 	"AgencyName"	TEXT,
# 	"FullAQSCode"	NUMERIC,
# 	"IntlAQSCode"	NUMERIC
# )

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///aqi.sqlite', echo=False)

# %%
from sqlalchemy import inspect
inspector = inspect(engine)

for table_name in inspector.get_table_names():
    print(table_name)
# Out:
# output
# sqlite_sequence

# %%
output_aqi.columns
# Out:
# Index(['AQI', 'AgencyName', 'Category', 'FullAQSCode', 'IntlAQSCode',
#        'Latitude', 'Longitude', 'Parameter', 'SiteName', 'UTC', 'Unit'],
#       dtype='object')

# %%
output_aqi.to_sql('output', con=engine, if_exists='append', index=False)
